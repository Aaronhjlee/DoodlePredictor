# %%
from load_clean_data import *
from plot import *

# %%
# %%time
df, df2, face_df, eye_df, nose_df, ear_df = get_clean_data()
# Out:
# loaded data
# merged data
# merged data
# merged data
# merged data
# taken samples
# taken samples
# taken samples
# taken samples
# clean and merged
# clean and merged
# CPU times: user 5min 3s, sys: 5.35 s, total: 5min 8s
# Wall time: 5min 10s

# %%
# %%time
plot_simple_all(face_df, eye_df, nose_df, ear_df)
# Out:
# CPU times: user 1.36 s, sys: 29.5 ms, total: 1.39 s
# Wall time: 1.4 s

# %%
# %%time
plot_var_comp(df, df2)
# Out:
# CPU times: user 5.03 s, sys: 309 ms, total: 5.34 s
# Wall time: 1.9 s

# %%
# %%time
plot_faces(df)
# Out:
# CPU times: user 87.8 ms, sys: 5.92 ms, total: 93.8 ms
# Wall time: 94.5 ms

# %%
# %%time
plot_2d_pca(df, df2)
# Out:
# CPU times: user 3.18 s, sys: 235 ms, total: 3.42 s
# Wall time: 1.7 s

# %%
# %%time
plot_3d_pca(df, df2)
# Out:
# CPU times: user 6.74 s, sys: 478 ms, total: 7.22 s
# Wall time: 7.91 s

# %%
# %%time
get_model_score(df, df2, GradientBoostingClassifier)
